# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
from scipy.stats import bernoulli
import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

import matplotlib.pyplot as plt

# %%
"""
Calculate:
p = probability that the fruit is an apple 
q = probability that the fruit is an orange 
"""

# your code here
p_apple = 0.6
p_orange = 0.4

# %%
apple_bernoulli = bernoulli(p_apple)
apple_bernoulli.rvs(100)

sample = apple_bernoulli.rvs(size=100)
sns.countplot(x=sample)

# 0 stands for oranges and 1 for apples.
# Out:
# <AxesSubplot: ylabel='count'>

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 1. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
# your code here
apple_bernoulli = bernoulli(p_apple)
apple_bernoulli.rvs(20)

# for the 1st experiment, we look at 5 first cases:
p_five_apples = p_apple ** 5
print(f'The probability that the first five fruits are apples is {p_five_apples}.')

# for the 2nd, we multiply p_five_apples * p_fifteen_oranges, since as we take a fruit, it is replaced by the same type (events are independent).
p_fifteen_oranges = p_orange ** 15
print(f'The probability that the first five fruits are apples and the next fifteen are oranges is {p_five_apples*p_fifteen_oranges}.')
# Out:
# The probability that the first five fruits are apples is 0.07775999999999998.
# The probability that the first five fruits are apples and the next fifteen are oranges is 8.349416423424006e-08.

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %%
# your code here
from scipy.stats import binom
apple_binomial = binom(20, 0.6)
print(f'The probability to have 5 apples in total out of 20 fruits is {apple_binomial.pmf(5)}.')
# Out:
# The probability to have 5 apples in total out of 20 fruits is 0.0012944935222876583.

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
# your code here
print(f'The probability to have less than 5 apples in total out of 20 fruits is {apple_binomial.cdf(4)}.')
# Out:
# The probability to have less than 5 apples in total out of 20 fruits is 0.00031703112116863004.

# %% [markdown]
# **Plot the PDF (probability distributiom function) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
# your code here
# Please label the axes and give a title to the plot
sns.countplot(x=apple_binomial.rvs(20), palette="Blues")
plt.xlabel('Number of apples picked')
plt.ylabel('Number of events with same outcome')
plt.title('Apples picked per event')
# Out:
# Text(0.5, 1.0, 'Apples picked per event')

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# ```

# %%
# your code here 
from scipy.stats import poisson
import numpy as np
print(f'The probability that 5 goles are scored if the average is 2.3 is:{poisson.pmf(k=5, mu=2.3)}.')
# Out:
# The probability that 5 goles are scored if the average is 2.3 is:0.053775025581946814.

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
# your code here
# Please label the axes and give a title to the plot 
x = np.arange(0,11,1)
y = poisson.pmf(x, 2.3, 0)

# %%
plt.plot(x,y)
