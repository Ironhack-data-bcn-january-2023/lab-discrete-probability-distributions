# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
import numpy as np
import math
from scipy.stats import bernoulli, binom, poisson

#Plotting
from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'

import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

# %%
"""
Calculate:
p = probability that the fruit is an apple 
q = probability that the fruit is an orange
"""

p = 60/100
q = 40/100

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 1. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
# The probability of getting 5 continious apples, since we are replacing the fruit is always p. So we multiply this probabillity by the consecutive amount of apples we want.
first_five_apple = p**5
print(round(first_five_apple, 3))

# Same goes for the next 15 being oranges.
next_15_all_oranges = q**15

# Since in our scenario we are strictly getting the first 5 as apples and the next 15 as oranges, we do not need to take into consideration all possiblle combinations.
second_scenario = first_five_apple*next_15_all_oranges
print(round(second_scenario,3)) # with the specified rounding, the result is 0. But note that it is not exactly 0.
# Out:
# 0.078
# 0.0

# %%
# expected results 👇🏾
# 1. 0.078
# 2. 8.349416423424006e-08

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %%
# Since the order does not matter now and we need to take into account all possible combinations of samples of 20 that contain 5 apples, we will use the binomial distribution.
five_apples = binom(20,p).pmf(5)
round(five_apples,3)
# Out:
# 0.001

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
less_than_5_apples = binom(20,p).cdf(4)
round(less_than_5_apples,3) # With the specified rounding, the result is 0. But note that it is not exactly 0, there is just a very slim chance of this happening.
# Out:
# 0.0

# %%
# expected results 👇🏾
# 1. 0.0012944935
# 2. 0.0003170311

# %% [markdown]
# **Plot the PDF (probability distributiom function) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
x = np.arange(0,20)
y = binom(20,p).pmf(x)
plt.plot(x,y)
# Please label the axes and give a title to the plot
plt.xlabel("No. of apples in the sample")
plt.ylabel("Probability")
plt.title("Probability distribution of picking apples from a 20 fruit basket p=0.6", size=24);

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# ```

# %%
lam=2.3
five_goals = poisson(lam).pmf(5)
round(five_goals,3)
# Out:
# 0.054

# %%
# expected results 👇🏾
# 1. 0.0537750255819468

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
x = np.arange(0,10)
y = poisson(lam).pmf(x)
plt.plot(x,y)
# Please label the axes and give a title to the plot
plt.xlabel("No. of goals in a match")
plt.ylabel("Probability")
plt.title("Probability distribution of goals in a UEFA Champions League match (poisson 2.3)", size=24);
