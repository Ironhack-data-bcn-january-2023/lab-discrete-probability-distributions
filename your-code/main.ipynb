# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
from scipy.stats import bernoulli
from scipy.stats import binom
import numpy as np
# Viz mantra
from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'
import math
from scipy.stats import poisson
import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

# %%
"""
Calculate:
p = probability that the fruit is an apple 
q = probability that the fruit is an orange
"""
qty_apples = 60
qty_oranges = 40
p_apples = qty_apples/(qty_apples+qty_oranges)
p_orange = qty_oranges/(qty_apples+qty_oranges)
print(f'Probability of getting an apple: {p_apples}')
print(f'Probability of getting an orange: {p_orange}')
# Out:
# Probability of getting an apple: 0.6
# Probability of getting an orange: 0.4

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 1. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
bernuolli_apple = bernoulli(p_apples)
bernuolli_apple.rvs(20)
first_5_apple = (p_apples ** 5)
print(f'Probability of getting first 5 apples: {first_5_apple}')
first_5_apple_rest_orange = first_5_apple*(p_orange**15)
print(f'Probability of getting first 5 apples and 15 oranges: {first_5_apple_rest_orange}')
# Out:
# Probability of getting first 5 apples: 0.07775999999999998
# Probability of getting first 5 apples and 15 oranges: 8.349416423424006e-08

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %%
apple_binom = binom(20,p_apples)
getting_5_apples = apple_binom.pmf(5)
print( f'Probability of getting 5 apples no matter the order: {getting_5_apples}')
# Out:
# Probability of getting 5 apples no matter the order: 0.0012944935222876587

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
getting_less_5_apples = apple_binom.cdf(4)
print( f'Probability of getting less than 5 apples: {getting_less_5_apples}')
# Out:
# Probability of getting less than 5 apples: 0.00031703112116863004

# %% [markdown]
# **Plot the PDF (probability distributiom function) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
range_sample = np.arange(0,20)
pdf = apple_binom.pmf(range_sample)
plt.plot(range_sample,pdf)
plt.xlabel('Amount of apples')
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# ```

# %%
lam = 2.3
football_posion = poisson(lam)
five_goals = football_posion.pmf(5)
print(f'Probability of scoring 5 goals in a math: {five_goals}')
# Out:
# Probability of scoring 5 goals in a math: 0.053775025581946814

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
x = np.arange(0, 11)
y = football_posion.pmf(x)

# Plot the Poisson probability distribution
plt.plot(x, y,'bo', ms=8)
plt.vlines(x, 0, y, colors='b', lw=5, alpha=0.5)
plt.xlabel('Number of goals')
plt.ylabel('Probability')
plt.title('Poisson probability distribution for football goals with lambda = 2.3')
plt.show()
